# %%
import pandas as pd

# %%
df = pd.read_csv('npr.csv')
df.head()
# Out:
#                                              Article
# 0  In the Washington of 2016, even when the polic...
# 1    Donald Trump has used Twitter  —   his prefe...
# 2    Donald Trump is unabashedly praising Russian...
# 3  Updated at 2:50 p. m. ET, Russian President Vl...
# 4  From photography, illustration and video, to d...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')

# %%
dtm = tfidf.fit_transform(df['Article'])

# %%
from sklearn.decomposition import NMF
nmf = NMF(n_components=7, random_state=42)

# %%
nmf.fit(dtm)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#     n_components=7, random_state=42, shuffle=False, solver='cd', tol=0.0001,
#     verbose=0)

# %%
tfidf.get_feature_names()[2300]
# Out:
# 'albala'

# %%
for index, topic in enumerate(nmf.components_):
    print(f"The TOP WORDS for TOPIC #{index}")
    print([tfidf.get_feature_names()[i] for i in topic.argsort()[-15:]])
    print('\n')
# Out:
# The TOP WORDS for TOPIC #0
# ['new', 'research', 'like', 'patients', 'health', 'disease', 'percent', 'women', 'virus', 'study', 'water', 'food', 'people', 'zika', 'says']
#
#
# The TOP WORDS for TOPIC #1
# ['gop', 'pence', 'presidential', 'russia', 'administration', 'election', 'republican', 'obama', 'white', 'house', 'donald', 'campaign', 'said', 'president', 'trump']
#
#
# The TOP WORDS for TOPIC #2
# ['senate', 'house', 'people', 'act', 'law', 'tax', 'plan', 'republicans', 'affordable', 'obamacare', 'coverage', 'medicaid', 'insurance', 'care', 'health']
#
#
# The TOP WORDS for TOPIC #3
# ['officers', 'syria', 'security', 'department', 'law', 'isis', 'russia', 'government', 'state', 'attack', 'president', 'reports', 'court', 'said', 'police']
#
#
# The TOP WORDS for TOPIC #4
# ['primary', 'cruz', 'election', 'democrats', 'percent', 'party', 'delegates', 'vote', 'state', 'democratic', 'hillary', 'campaign', 'voters', 'sanders', 'clinton']
#
#
# The TOP WORDS for TOPIC #5
# ['love', 've', 'don', 'album', 'way', 'time', 'song', 'life', 'really', 'know', 'people', 'think', 'just', 'music', 'like']
#
#
# The TOP WORDS for TOPIC #6
# ['teacher', 'state', 'high', 'says', 'parents', 'devos', 'children', 'college', 'kids', 'teachers', 'student', 'education', 'schools', 'school', 'students']

# %%
topic_results = nmf.transform(dtm)

# %%
topic_results[0].argmax()
# Out:
# 1

# %%
topic_results.argmax(axis=1)
# Out:
# array([1, 1, 1, ..., 0, 4, 3], dtype=int64)

# %%
df['Topic'] = topic_results.argmax(axis=1)

# %%
'''

my_dict = {1:'Politics', 2:'',3:,4:}
df['Topic Names'] = df['Topic'].map(my_dict)

'''
# Out:
# "\n\nmy_dict = {1:'Politics', 2:'',3:,4:}\ndf['Topic Names'] = df['Topic'].map(my_dict)\n\n"

# %%
df.head(100)
# Out:
#                                               Article  Topic
# 0   In the Washington of 2016, even when the polic...      1
# 1     Donald Trump has used Twitter  —   his prefe...      1
# 2     Donald Trump is unabashedly praising Russian...      1
# 3   Updated at 2:50 p. m. ET, Russian President Vl...      3
# 4   From photography, illustration and video, to d...      6
# 5   I did not want to join yoga class. I hated tho...      5
# 6   With a   who has publicly supported the debunk...      0
# 7   I was standing by the airport exit, debating w...      0
# 8   If movies were trying to be more realistic, pe...      0
# 9   Eighteen years ago, on New Year’s Eve, David F...      5
# 10  For years now, some of the best, wildest, most...      5
# 11  For years now, some of the best, wildest, most...      5
# 12  The Colorado River is like a giant bank accoun...      0
# 13  For the last installment of NPR’s holiday reci...      5
# 14  Being overweight can raise your blood pressure...      0
# 15  Who’s the YouTube star of 2016? Adele singing ...      5
# 16  Here’s a quick roundup of some of the   you ma...      3
# 17  Ben Johnston doesn’t follow the rules of music...      5
# 18  David Bowie, Prince and George Michael are all...      5
# 19  In November, the typically straitlaced Office ...      1
# 20  This is the time of year when everybody is mak...      5
# 21  Terrorist attacks, hurricanes, a divisive U. S...      5
# 22  We all experience stress at work, no matter th...      6
# 23  When John Fahey recorded The New Possibility i...      5
# 24  This year was one of   hacks, exploding smartp...      5
# 25  From West Virginia to Wyoming, coal country ov...      1
# 26  Updated Jan. 1 at 9:56 a. m. ET, At least 39 p...      3
# 27  On the morning of Jan. 1, Los Angeles resident...      3
# 28  In September, reproductive endocrinologist Joh...      0
# 29  In an effort to take advantage of the intimate...      0
# ..                                                ...    ...
# 70  After a storm of criticism, including from   D...      1
# 71  Fox News anchor Megyn Kelly is leaving the cab...      1
# 72  When spirits entrepreneur Steven Grasse consid...      5
# 73  Every year in the U. S. more than 30, 000 peop...      0
# 74     Demarco Webster Jr. was helping his dad mov...      3
# 75  Ah, to work in France: plenty of vacation and ...      0
# 76  Viridiana Martinez’s parents brought her to th...      3
# 77  Beijing’s sky appears blue at the beginning of...      0
# 78  It’s 1968 in New Bordeaux, La. On the surface ...      5
# 79  One in five Americans is religiously unaffilia...      4
# 80  Updated at 1 p. m. ET, Turkish authorities mad...      3
# 81  When   Miranda was a teenager in the 1990s, he...      5
# 82  Opening punches were thrown in what one top De...      2
# 83  Desmond Tutu, South Africa’s former Anglican a...      3
# 84  If you’re looking for a diet plan that suits y...      0
# 85  Rex Tillerson,   Donald Trump’s nominee for U....      3
# 86  Dylann Roof delivered his opening statement in...      3
# 87  A crowded commuter train crashed into a bumper...      3
# 88  Amid this week’s firestorm over Republicans’ a...      5
# 89  Louisiana is losing its coast at a rapid rate ...      0
# 90  Murmuration refers to the phenomenon that resu...      5
# 91  Armed men reportedly attacked a jail in the Ph...      3
# 92  Frenchman Robert Marchand set a new world reco...      5
# 93  People think of black holes as nightmare vacuu...      5
# 94  Several civil rights activists were arrested T...      3
# 95  Vocalist Xenia Rubinos ended 2016 with a bang:...      5
# 96  Imagine being able to collect the DNA of a hum...      0
# 97  The machinery inside Conner Bottling Works doe...      0
# 98  An Israeli military court has convicted a sold...      3
# 99  ”Dogs are better than human beings,” wrote Emi...      5
#
# [100 rows x 2 columns]
